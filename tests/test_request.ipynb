# %%
import librosa
import io
import requests
import time
from utils.serializers import ndarray_to_bytes

def max_request(signal, url, topN=None) -> dict:
    audio_bytes = ndarray_to_bytes(signal)
    buf = io.BytesIO()
    buf.write(audio_bytes)
    # sf.write(buf, signal, fs, format='WAV', endian='LITTLE', subtype='PCM_16')
    buf.seek(0)
    
    if topN is not None:
        url += '?topN={:d}'.format(topN)
        
    response = (requests.post(url, files={"audio": buf})).json()
    # print(response.json())
    
    return response["predictions"], response["music_score"]


if __name__ == "__main__":
    #file = "/home/joao/Desktop/Ecad/database/audio/tasks/139743/139743.ogg"
    file = '/mnt/dev/dirceusilva/dados/Cover/setlist_65k/audio/tasks/139850/139850.ogg' 
    url_base = "http://localhost:5000/model/predict/bytes"

    signal, fs = librosa.load(file, mono=True, sr=16000)
    segment_signal = signal[:int(10 * fs)]
    segment_duration = 10  # 10s
    topN = 5

    samples_per_segment = fs * segment_duration
    num_segments = len(signal) // samples_per_segment
    start = time.time()
    predictions = []
    music_score = []
    for i in range(num_segments):
        start_sample = i * samples_per_segment
        end_sample = (i + 1) * samples_per_segment
        segment_signal = signal[start_sample:end_sample]
        classes, music_prob = max_request(signal=segment_signal, url=url_base, topN=topN)
        predictions.append({"classes":classes, "music_score": music_prob, "inicio":float(start_sample)/fs, "fim":float(end_sample)/fs })
        music_score.append(music_prob)
        
    # max_request(signal=signal)
    print(predictions)
    print(f"{time.time()-start}")
    print(f"Segment {num_segments}")
# Out:
# [{'classes': [{'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.718755841255188}, {'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.21202749013900757}, {'label_id': '/m/06bz3', 'label': 'Radio', 'probability': 0.2090735137462616}, {'label_id': '/m/02qldy', 'label': 'Narration, monologue', 'probability': 0.1998978555202484}, {'label_id': '/m/05zppz', 'label': 'Male speech, man speaking', 'probability': 0.14311254024505615}], 'music_score': [{'probability': 0.3076684496473547}], 'inicio': 0.0, 'fim': 10.0}, {'classes': [{'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.7725379467010498}, {'label_id': '/m/02qldy', 'label': 'Narration, monologue', 'probability': 0.3497442603111267}, {'label_id': '/m/06bz3', 'label': 'Radio', 'probability': 0.3200596570968628}, {'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.27501922845840454}, {'label_id': '/m/05zppz', 'label': 'Male speech, man speaking', 'probability': 0.26242685317993164}], 'music_score': [{'probability': 0.3248666477850463}], 'inicio': 10.0, 'fim': 20.0}, {'classes': [{'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.6972918510437012}, {'label_id': '/m/02qldy', 'label': 'Narration, monologue', 'probability': 0.3905033469200134}, {'label_id': '/m/05zppz', 'label': 'Male speech, man speaking', 'probability': 0.294996440410614}, {'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.27166444063186646}, {'label_id': '/m/06bz3', 'label': 'Radio', 'probability': 0.10590974241495132}], 'music_score': [{'probability': 0.3278735690428518}], 'inicio': 20.0, 'fim': 30.0}, {'classes': [{'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.6442255973815918}, {'label_id': '/m/07qcpgn', 'label': 'Tap', 'probability': 0.13061299920082092}, {'label_id': '/m/07qv_x_', 'label': 'Shuffle', 'probability': 0.09074050188064575}, {'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.05926808714866638}, {'label_id': '/m/02dgv', 'label': 'Door', 'probability': 0.054186880588531494}], 'music_score': [{'probability': 0.9387608234968721}], 'inicio': 30.0, 'fim': 40.0}, {'classes': [{'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.2701834440231323}, {'label_id': '/m/07qcpgn', 'label': 'Tap', 'probability': 0.06328430771827698}, {'label_id': '/m/0jbk', 'label': 'Animal', 'probability': 0.052553027868270874}, {'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.0458369255065918}, {'label_id': '/m/07qv4k0', 'label': 'Scrape', 'probability': 0.045324236154556274}], 'music_score': [{'probability': 0.8470772335434933}], 'inicio': 40.0, 'fim': 50.0}, {'classes': [{'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.7109619379043579}, {'label_id': '/m/04rmv', 'label': 'Mouse', 'probability': 0.10588666796684265}, {'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.093483567237854}, {'label_id': '/m/04szw', 'label': 'Musical instrument', 'probability': 0.07814401388168335}, {'label_id': '/m/07qwdck', 'label': 'Ping', 'probability': 0.07788583636283875}], 'music_score': [{'probability': 0.9145149983870421}], 'inicio': 50.0, 'fim': 60.0}, {'classes': [{'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.503773033618927}, {'label_id': '/m/07qcpgn', 'label': 'Tap', 'probability': 0.12568730115890503}, {'label_id': '/m/01jg02', 'label': 'Heart sounds, heartbeat', 'probability': 0.1061130166053772}, {'label_id': '/m/09x0r', 'label': 'Speech', 'probability': 0.08529305458068848}, {'label_id': '/m/07qv4k0', 'label': 'Scrape', 'probability': 0.05054253339767456}], 'music_score': [{'probability': 0.8862090203929986}], 'inicio': 60.0, 'fim': 70.0}, {'classes': [{'label_id': '/m/04rlf', 'label': 'Music', 'probability': 0.7206154465675354}, {'label_id': '/m/04szw', 'label': 'Musical instrument', 'probability': 0.1339688003063202}, {'label_id': '/m/0l14md', 'label': 'Percussion', 'probability': 0.058056920766830444}, {'label_id': '/m/02dgv', 'label': 'Door', 'probability': 0.05586621165275574}, {'label_id': '/m/026t ...
# 119.37800478935242
# Segment 1145

# %%
len(predictions)
# Out:
# 1145
